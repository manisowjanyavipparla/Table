# %% [markdown]
# <a href="https://colab.research.google.com/github/manisowjanyavipparla/Table/blob/main/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import io
import pandas as pd
import seaborn as sn
Sales=pd.read_excel("Sales Target.xlsm")
print(Sales)
# Out:
#     Order ID           Order Date CustomerName              State       City
# 0    B-25601  2018-01-04 00:00:00       Bharat            Gujarat  Ahmedabad
# 1    B-25602  2018-01-04 00:00:00        Pearl        Maharashtra       Pune
# 2    B-25603  2018-03-04 00:00:00        Jahan     Madhya Pradesh     Bhopal
# 3    B-25604  2018-03-04 00:00:00       Divsha          Rajasthan     Jaipur
# 4    B-25605  2018-05-04 00:00:00      Kasheen        West Bengal    Kolkata
# ..       ...                  ...          ...                ...        ...
# 495  B-26096           28-03-2019       Atharv        West Bengal    Kolkata
# 496  B-26097           28-03-2019         Vini          Karnataka  Bangalore
# 497  B-26098           29-03-2019        Pinky  Jammu and Kashmir    Kashmir
# 498  B-26099           30-03-2019       Bhishm        Maharashtra     Mumbai
# 499  B-26100           31-03-2019       Hitika     Madhya Pradesh     Indore
#
# [500 rows x 5 columns]

# %% [markdown]
# # New Section

# %%
import io
import pandas as pd
import seaborn as sns
Order=pd.read_excel("Order Details.xlsm")
print(Order)
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category
# 0     B-25601    1275   -1148         7    Furniture         Bookcases
# 1     B-25601      66     -12         5     Clothing             Stole
# 2     B-25601       8      -2         3     Clothing       Hankerchief
# 3     B-25601      80     -56         4  Electronics  Electronic Games
# 4     B-25602     168    -111         2  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-26099     835     267         5  Electronics            Phones
# 1496  B-26099    2366     552         5     Clothing          Trousers
# 1497  B-26100     828     230         2    Furniture            Chairs
# 1498  B-26100      34      10         2     Clothing           T-shirt
# 1499  B-26100      72      16         2     Clothing             Shirt
#
# [1500 rows x 6 columns]

# %%
import io
import pandas as pd
import seaborn as sns
List=pd.read_excel("List of Orders.xlsm")
print(List)
# Out:
#    Month of Order Date     Category  Target
# 0           2022-04-18    Furniture   10400
# 1           2022-05-18    Furniture   10500
# 2           2022-06-18    Furniture   10600
# 3           2022-07-18    Furniture   10800
# 4           2022-08-18    Furniture   10900
# 5           2022-09-18    Furniture   11000
# 6           2022-10-18    Furniture   11100
# 7           2022-11-18    Furniture   11300
# 8           2022-12-18    Furniture   11400
# 9           2022-01-19    Furniture   11500
# 10          2022-02-19    Furniture   11600
# 11          2022-03-19    Furniture   11800
# 12          2022-04-18     Clothing   12000
# 13          2022-05-18     Clothing   12000
# 14          2022-06-18     Clothing   12000
# 15          2022-07-18     Clothing   14000
# 16          2022-08-18     Clothing   14000
# 17          2022-09-18     Clothing   14000
# 18          2022-10-18     Clothing   16000
# 19          2022-11-18     Clothing   16000
# ...

# %%
Sales.head()
# Out:
#   Order ID           Order Date CustomerName           State       City
# 0  B-25601  2018-01-04 00:00:00       Bharat         Gujarat  Ahmedabad
# 1  B-25602  2018-01-04 00:00:00        Pearl     Maharashtra       Pune
# 2  B-25603  2018-03-04 00:00:00        Jahan  Madhya Pradesh     Bhopal
# 3  B-25604  2018-03-04 00:00:00       Divsha       Rajasthan     Jaipur
# 4  B-25605  2018-05-04 00:00:00      Kasheen     West Bengal    Kolkata

# %%
Order.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category
# 0  B-25601    1275   -1148         7    Furniture         Bookcases
# 1  B-25601      66     -12         5     Clothing             Stole
# 2  B-25601       8      -2         3     Clothing       Hankerchief
# 3  B-25601      80     -56         4  Electronics  Electronic Games
# 4  B-25602     168    -111         2  Electronics            Phones

# %%
Sales.shape
# Out:
# (500, 5)

# %%
Order.shape
# Out:
# (1500, 6)

# %%
List.shape
# Out:
# (36, 3)

# %%
#checking missing values
Order.isnull().sum()
# Out:
# Order ID        0
# Amount          0
# Profit          0
# Quantity        0
# Category        0
# Sub-Category    0
# dtype: int64

# %%
Order.describe()
# Out:
#             Amount       Profit     Quantity
# count  1500.000000  1500.000000  1500.000000
# mean    287.668000    15.970000     3.743333
# std     461.050488   169.140565     2.184942
# min       4.000000 -1981.000000     1.000000
# 25%      45.000000    -9.250000     2.000000
# 50%     118.000000     9.000000     3.000000
# 75%     322.000000    38.000000     5.000000
# max    5729.000000  1698.000000    14.000000

# %%
i=pd.merge(Order,List)
i
# Out:
#       Order ID  Amount  Profit  Quantity     Category Sub-Category  \
# 0      B-25601    1275   -1148         7    Furniture    Bookcases
# 1      B-25601    1275   -1148         7    Furniture    Bookcases
# 2      B-25601    1275   -1148         7    Furniture    Bookcases
# 3      B-25601    1275   -1148         7    Furniture    Bookcases
# 4      B-25601    1275   -1148         7    Furniture    Bookcases
# ...        ...     ...     ...       ...          ...          ...
# 17995  B-26099     835     267         5  Electronics       Phones
# 17996  B-26099     835     267         5  Electronics       Phones
# 17997  B-26099     835     267         5  Electronics       Phones
# 17998  B-26099     835     267         5  Electronics       Phones
# 17999  B-26099     835     267         5  Electronics       Phones
#
#       Month of Order Date  Target
# 0              2022-04-18   10400
# 1              2022-05-18   10500
# 2              2022-06-18   10600
# ...

# %%
data=i.groupby("Order ID").max()["Profit"].reset_index()#here,Order ID became a primary key
data
# Out:
#     Order ID  Profit
# 0    B-25601      -2
# 1    B-25602    1151
# 2    B-25603      36
# 3    B-25604      17
# 4    B-25605       0
# ..       ...     ...
# 495  B-26096      56
# 496  B-26097      18
# 497  B-26098     179
# 498  B-26099     552
# 499  B-26100     230
#
# [500 rows x 2 columns]

# %%
a=i[["Quantity","Profit"]]
a
# Out:
#        Quantity  Profit
# 0             7   -1148
# 1             7   -1148
# 2             7   -1148
# 3             7   -1148
# 4             7   -1148
# ...         ...     ...
# 17995         5     267
# 17996         5     267
# 17997         5     267
# 17998         5     267
# 17999         5     267
#
# [18000 rows x 2 columns]

# %%
b=i[["Amount","Profit"]]
b
# Out:
#        Amount  Profit
# 0        1275   -1148
# 1        1275   -1148
# 2        1275   -1148
# 3        1275   -1148
# 4        1275   -1148
# ...       ...     ...
# 17995     835     267
# 17996     835     267
# 17997     835     267
# 17998     835     267
# 17999     835     267
#
# [18000 rows x 2 columns]

# %%
List
# Out:
#    Month of Order Date     Category  Target
# 0           2022-04-18    Furniture   10400
# 1           2022-05-18    Furniture   10500
# 2           2022-06-18    Furniture   10600
# 3           2022-07-18    Furniture   10800
# 4           2022-08-18    Furniture   10900
# 5           2022-09-18    Furniture   11000
# 6           2022-10-18    Furniture   11100
# 7           2022-11-18    Furniture   11300
# 8           2022-12-18    Furniture   11400
# 9           2022-01-19    Furniture   11500
# 10          2022-02-19    Furniture   11600
# 11          2022-03-19    Furniture   11800
# 12          2022-04-18     Clothing   12000
# 13          2022-05-18     Clothing   12000
# 14          2022-06-18     Clothing   12000
# 15          2022-07-18     Clothing   14000
# 16          2022-08-18     Clothing   14000
# 17          2022-09-18     Clothing   14000
# 18          2022-10-18     Clothing   16000
# 19          2022-11-18     Clothing   16000
# ...

# %%
a=df[["State","Profit"]]
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1439b77bf274> in <module>()
# ----> 1 df=pd.merge(Sales,Order)
#       2 df
#       3 a=df[["State","Profit"]]
#       4 a
#
# NameError: name 'pd' is not defined

# %%
import seaborn as sns
sns.boxplot(x="Category",y="Profit",data=Order)
#Here we can observe which category has more profit

# %%
sns.boxplot(x="Sub-Category",y="Profit",data=Order)

# %%
most_sell_prod=pd.DataFrame(df.groupby("Sub-Category").sum()["Quantity"])

# %%
most_sell_prod=most_sell_prod.sort_values("Quantity",ascending=False)

# %%
most_sell_prod[:10]
# Out:
#                   Quantity
# Sub-Category
# Saree                  782
# Hankerchief            754
# Stole                  671
# Furnishings            310
# T-shirt                305
# Phones                 304
# Electronic Games       297
# Bookcases              297
# Printers               291
# Chairs                 277

# %%
pd.DataFrame(df.groupby(["Category","Sub-Category"]).sum()["Profit"])
# Out:
#                               Profit
# Category    Sub-Category
# Clothing    Hankerchief         2098
#             Kurti                181
#             Leggings             260
#             Saree                352
#             Shirt               1131
#             Skirt                235
#             Stole               2559
#             T-shirt             1500
#             Trousers            2847
# Electronics Accessories         3559
#             Electronic Games   -1236
#             Phones              2207
#             Printers            5964
# Furniture   Bookcases           4888
#             Chairs               577
#             Furnishings          844
#             Tables             -4011

# %%
correlation=Order.corr()

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)

# %%
sns.pairplot(Order)

# %%
Correlation=Sales.corr()

# %%
sns.pairplot(Sales)

# %%
sns.relplot(x="Order ID",y="Profit",data=Order)
